# %% [markdown]
# ## はじめに

# %% [markdown]
# [Scala](https://www.scala-lang.org) プログラミング入門用の [Jupyter](http://jupyter.org) ノートブック ([Almond](https://almond.sh) Scala kernelを利用)を提供している．
# 元のGitHubサイトは [https://github.com/tamura70/scala-introduction/>](https://github.com/tamura70/scala-introduction/>)である．

# %% [markdown]
# ## コンテンツ

# %% [markdown]
# 以下の内容はWebページ  [Scalaプログラミング入門](http://bach.istc.kobe-u.ac.jp/lect/ProLang/org/scala.html) に基づいている．
#
# -   [Scalaでオブジェクト指向](scala-oop.ipynb)
