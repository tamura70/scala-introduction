# %% [markdown]
# ## はじめに

# %% [markdown]
# [Scala](https://www.scala-lang.org) プログラミング入門用の [Jupyter](http://jupyter.org) ノートブック ([Almond](https://almond.sh) Scala kernelを利用)を提供している．
# 以下のURLをクリックするとWebブラウザ上で実行できる!
#
# -   [https://mybinder.org/v2/gh/tamura70/scala-introduction/master?urlpath=lab/tree/README.ipynb](https://mybinder.org/v2/gh/tamura70/scala-introduction/master?urlpath=lab/tree/README.ipynb)
#
# 内容は以下のWebページに基づいている．
#
# -   [Scalaプログラミング入門](http://bach.istc.kobe-u.ac.jp/lect/ProLang/org/scala.html)
#
# Blenderのセットアップスクリプトは [Almond Examples](https://github.com/almond-sh/examples) から入手した．

# %% [markdown]
# ## Credits/Links

# %% [markdown]
# -   [Scala](https://www.scala-lang.org)
# -   [Jupyter](http://jupyter.org)
# -   [Almond](https://almond.sh)
# -   [Binder](https://mybinder.org)
